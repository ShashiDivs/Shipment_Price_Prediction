# %%
import pandas as pd

# %%
pwd
# Out:
# 'd:\\Projects_MachineLearning\\Shipment_price\\Notebook'

# %%
df = pd.read_csv("d:\\Projects_MachineLearning\\Shipment_price\\Data\\train.csv")

# %%
df
# Out:
#       Artist Reputation  Height  Width     Weight   Material  \
# 0                  0.19    35.0   21.0    89371.0      Brass
# 1                  0.70    25.0    6.0   139475.0      Stone
# 2                  0.47    32.0    7.0      287.0       Wood
# 3                  0.27    37.0   17.0     1927.0  Aluminium
# 4                  0.62    30.0   11.0   445451.0      Stone
# ...                 ...     ...    ...        ...        ...
# 2684               0.12    37.0   22.0     7403.0  Aluminium
# 2685               0.01    12.0    6.0      376.0  Aluminium
# 2686               0.78    34.0   21.0  7285369.0      Stone
# 2687               0.13    36.0   23.0      981.0       Wood
# 2688               0.04    15.0    6.0    52906.0      Stone
#
#       Price Of Sculpture  Base Shipping Price International Express Shipment  \
# 0                 194.63                39.70           Yes               No
# ...

# %%
import pymongo
from pymongo.mongo_client import MongoClient

# %%
# !python -m pip install "pymongo[srv]"

# %%
data = df.to_dict(orient="records")
data
# Out:
# [{'Artist Reputation': 0.19,
#   'Height': 35.0,
#   'Width': 21.0,
#   'Weight': 89371.0,
#   'Material': 'Brass',
#   'Price Of Sculpture': 194.63,
#   'Base Shipping Price': 39.7,
#   'International': 'Yes',
#   'Express Shipment': 'No',
#   'Installation Included': 'No',
#   'Transport': 'Airways',
#   'Fragile': 'No',
#   'Customer Information': 'Working Class',
#   'Remote Location': 'No',
#   'Cost': 938.77},
#  {'Artist Reputation': 0.7,
#   'Height': 25.0,
#   'Width': 6.0,
#   'Weight': 139475.0,
#   'Material': 'Stone',
#   'Price Of Sculpture': 159.1,
#   'Base Shipping Price': 30.76,
#   'International': 'No',
#   'Express Shipment': 'No',
#   'Installation Included': 'No',
#   'Transport': 'Roadways',
#   'Fragile': 'No',
#   'Customer Information': 'Working Class',
#   'Remote Location': 'No',
#   'Cost': 1164.3},
#  {'Artist Reputation': 0.47,
#   'Height': 32.0,
#   'Width': 7.0,
#   'Weight': 287.0,
#   'Material': 'Wood',
#   'Price Of Sculpture': 4.18,
# ...

# %%
import pymongo

# Replace these with your MongoDB connection details
mongo_uri = "mongodb+srv://shashingit:divyashashi@cluster0.g3ja9af.mongodb.net/?retryWrites=true&w=majority"
database_name = "shipping"
collection_name = "shipping_data"


# Connect to MongoDB
client = pymongo.MongoClient(mongo_uri)
database = client[database_name]
collection = database[collection_name]

# Insert data into the collection
collection.insert_many(data)

# Close the connection
client.close()

print("Data uploaded successfully.")
# Out:
# Data uploaded successfully.
